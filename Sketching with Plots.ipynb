# %% [markdown]
# You can generate quick and effective plots using only pandas' built-in plotting capabilities, which are powered by Matplotlib under the hood but require no additional setup. This method is ideal for quick data exploration and uncovering insights without needing to write much code.
#
# Be sure to try the code in your IDE.
#
# For example, if you have a dataset of sales data and want to see the distribution of sales amounts, you can create a histogram directly using pandas:

# %%
import pandas as pd

# Sample DataFrame
df = pd.DataFrame({'sales': [100, 150, 200, 250, 300, 1000]})

# Quick histogram to visualize sales distribution
df['sales'].plot(kind='hist', bins=10, title='Sales Distribution')
# Out:
# <Axes: title={'center': 'Sales Distribution'}, ylabel='Frequency'>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# url to the data set and reading in the data 
url = 'https://raw.githubusercontent.com/CodeYouOrg/DataOpenClass/refs/heads/main/SalaryData.csv'
df = pd.read_csv(url)

# dropping columns we dont need
columns_to_drop = ['Overtime_Rate',	'Incentive_Allowance', 'Other', 'ObjectId']
df = df.drop(columns=columns_to_drop)

# We dont have a ton of missing data so we are dropping the NaNs 
df = df.dropna()

# filtering the data to year 2024
filtered_data = df[df['CalYear'] == 2024]

# Filter out rows where jobTitle contains 'chief' or 'director'... (case-insensitive)
filtered_data = filtered_data[~filtered_data['jobTitle'].str.contains('chief|director|Major|Sergeant|General|Manager|Mayor|Lieutenant|Senior|Commander|Supervisor', case=False, na=False)]

# grouping department together and sorting them 
department_total = filtered_data.groupby(['Department', 'jobTitle'])['YTD_Total'].mean()
department_total = department_total.sort_values(ascending=False)

# Disable scientific notation for pandas
pd.set_option('display.float_format', '{:,.0f}'.format)

print("The top 10 departments by salary spend is:\n", department_total.head(10))

# Plotting the top 10 non-senior roles by total salary
department_total.head(10).plot(kind='bar',
                               figsize=(6, 8),
                               title='Total Salary by Department and Title')

plt.xlabel('Department and Title')
plt.ylabel('Total Salary')
plt.xticks(rotation=90, ha='right')
plt.tight_layout()
plt.show()
# Out:
# The top 10 departments by salary spend is:
#  Department                     jobTitle
# Emergency Management Services  EMS EMT-Paramedic II           146,616
# Metro Technology Services      Information Security Officer   134,614
#                                IT Asset Coordinator           127,130
# Criminal Justice Commission    Executive Liaison              126,091
# Department of Corrections      Corrections Deputy             124,943
# Metro Technology Services      Executive Administrator        120,379
#                                Systems Engineer III           118,127
# Human Resources                Labor Relations Negotiator     115,431
# Metro Technology Services      Data Engineer II               113,793
# Louisville Fire                Fire Arson Investigator II     112,199
# Name: YTD_Total, dtype: float64

# %%
import pandas as pd
import matplotlib.pyplot as plt

# url to the data set and reading in the data 
url = 'https://raw.githubusercontent.com/CodeYouOrg/DataOpenClass/refs/heads/main/SalaryData.csv'
df = pd.read_csv(url)

# dropping columns we dont need
columns_to_drop = ['Overtime_Rate',	'Incentive_Allowance', 'Other', 'ObjectId']
df = df.drop(columns=columns_to_drop)

# We dont have a ton of missing data so we are dropping the NaNs 
df = df.dropna()

# filtering the data to year 2024
filtered_data = df[df['CalYear'] == 2024]

# Filter out rows where jobTitle contains 'chief' or 'director' (case-insensitive)
filtered_data = filtered_data[~filtered_data['jobTitle'].str.contains('chief|director|Major|Sergeant|General|Manager|Mayor|Lieutenant|Senior|Commander|Supervisor', case=False, na=False)]

# grouping department together and sorting them 
department_total = filtered_data.groupby(['Department', 'jobTitle'])['YTD_Total'].mean()
department_total = department_total.sort_values(ascending=False)

# Disable scientific notation for pandas
pd.set_option('display.float_format', '{:,.0f}'.format)
print("The top 10 departments by salary spend is:\n", department_total.head(10))


department_total.head(10).plot(kind = 'bar',
                               xlabel = 'Department and Title',
                               ylabel = 'Total Salary',
                               title = 'Total Salary by Department and Title')
plt.show()
# Out:
# The top 10 departments by salary spend is:
#  Department                     jobTitle
# Emergency Management Services  EMS EMT-Paramedic II           146,616
# Metro Technology Services      Information Security Officer   134,614
#                                IT Asset Coordinator           127,130
# Criminal Justice Commission    Executive Liaison              126,091
# Department of Corrections      Corrections Deputy             124,943
# Metro Technology Services      Executive Administrator        120,379
#                                Systems Engineer III           118,127
# Human Resources                Labor Relations Negotiator     115,431
# Metro Technology Services      Data Engineer II               113,793
# Louisville Fire                Fire Arson Investigator II     112,199
# Name: YTD_Total, dtype: float64

# %%
import pandas as pd
import matplotlib.pyplot as plt

url = 'https://raw.githubusercontent.com/CodeYouOrg/DataOpenClass/refs/heads/main/SalaryData.csv'
df = pd.read_csv(url)

# dropping columns we dont need
columns_to_drop = ['Overtime_Rate',	'Incentive_Allowance', 'Other', 'ObjectId']
df = df.drop(columns=columns_to_drop)

# We dont have a ton of missing data so we are dropping the NaNs 
df = df.dropna()

# Filter for year 2022 and salary >= 100,000
df = df[(df['CalYear'] == 2022) & (df['YTD_Total'] >= 100000)]

# Sort by salary and take top 10
df = df.sort_values(by='YTD_Total', ascending=False).head(10)

#print(top_10)

df.head(10).plot(kind = 'bar', xlabel = 'Employee_Name', ylabel = 'YTD_Total', title = 'Top 10 Salaries in 2022')

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

url = 'https://raw.githubusercontent.com/CodeYouOrg/DataOpenClass/refs/heads/main/SalaryData.csv'
df = pd.read_csv(url)

# dropping columns we dont need
columns_to_drop = ['Overtime_Rate',	'Incentive_Allowance', 'Other', 'ObjectId']
df = df.drop(columns=columns_to_drop)

# We dont have a ton of missing data so we are dropping the NaNs 
df = df.dropna()

# Filter for year 2022 and salary >= 100,000
df = df[(df['CalYear'] == 2022) & (df['YTD_Total'] >= 100000)]

# Sort by salary and take top 10
# top_10 = df.sort_values(by='YTD_Total', ascending=False).head(10)

print(top_10)
# Out:
#        CalYear          Employee_Name                          Department  \
# 31077     2022         Shields, Erika  Louisville Metro Police Department
# 26752     2022     Miller, Russell J.  Louisville Metro Police Department
# 27309     2022  Lokits, Christopher T       Emergency Management Services
# 27486     2022      Keller, Matthew J  Louisville Metro Police Department
# 27070     2022          Fey, Ronald W  Louisville Metro Police Department
# 26374     2022      Hudson, Daryell W                     Louisville Fire
# 26762     2022        Murphy, Paul P.                     Louisville Fire
# 31741     2022      Maloney, Daniel K                      Louisville Zoo
# 26235     2022   Frederick, Gregory W                     Louisville Fire
# 27064     2022     McCubbins, Joe Lee           Department of Corrections
#
#                            jobTitle  Annual_Rate  Regular_Rate  YTD_Total
# 31077                  Police Chief      238,277       235,572    262,051
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

url = 'https://raw.githubusercontent.com/CodeYouOrg/DataOpenClass/refs/heads/main/SalaryData.csv'
df = pd.read_csv(url)

# dropping columns we dont need
columns_to_drop = ['Overtime_Rate',	'Incentive_Allowance', 'Other', 'ObjectId']
df = df.drop(columns=columns_to_drop)

# We dont have a ton of missing data so we are dropping the NaNs 
df = df.dropna()

df = df[(df['CalYear'] == 2022) & (df['YTD_Total'] >= 100000)]


df = df.sort_values(by='YTD_Total', ascending=False)

df.head(10).plot(kind="bar", x="Employee_Name", y="YTD_Total", title="Top 10 Salaries in 2022")

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

url = 'https://raw.githubusercontent.com/CodeYouOrg/DataOpenClass/refs/heads/main/SalaryData.csv'
df = pd.read_csv(url)

# dropping columns we dont need
columns_to_drop = ['Overtime_Rate',	'Incentive_Allowance', 'Other', 'ObjectId']
df = df.drop(columns=columns_to_drop)

# We dont have a ton of missing data so we are dropping the NaNs 
df = df.dropna()

df = df[(df['CalYear'] == 2022) & (df['YTD_Total'] >= 100000)]


df = df.sort_values(by='YTD_Total', ascending=False)

print(df)
# Out:
#        CalYear              Employee_Name                          Department  \
# 31077     2022             Shields, Erika  Louisville Metro Police Department
# 26752     2022         Miller, Russell J.  Louisville Metro Police Department
# 27309     2022      Lokits, Christopher T       Emergency Management Services
# 27486     2022          Keller, Matthew J  Louisville Metro Police Department
# 27070     2022              Fey, Ronald W  Louisville Metro Police Department
# ...        ...                        ...                                 ...
# 26459     2022             Webb, Joshua A                     Louisville Fire
# 28937     2022      Reilly, Trent Stephen  Louisville Metro Police Department
# 27488     2022            King, Matthew B                                APCD
# 29509     2022  Westenhofer, Jeffrey Paul               Public Works & Assets
# 26415     2022              McCoy, Alma P                      ES & MetroSafe
#
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

url = 'https://raw.githubusercontent.com/CodeYouOrg/DataOpenClass/refs/heads/main/SalaryData.csv'
df = pd.read_csv(url)

# dropping columns we dont need
columns_to_drop = ['Overtime_Rate',	'Incentive_Allowance', 'Other', 'ObjectId']
df = df.drop(columns=columns_to_drop)

# We dont have a ton of missing data so we are dropping the NaNs 
df = df.dropna()

df = df[(df['CalYear'] == 2022) & (df['YTD_Total'] >= 100000)]


df = df.sort_values(by='YTD_Total', ascending=False)

df.head(10).plot(kind="bar", x="Employee_Name", y="YTD_Total", title="Top 10 Salaries in 2022")

plt.show()
